# %% [markdown]
# # Curso de Manejo de Datos Faltantes: Detección y Exploración
#
# [![Curso creado por jvelezmagic](https://img.shields.io/badge/Desarrollado%20por-%40jvelezmagic-blue?&style=for-the-badge&logo=data:image/png;base64,...)](https://jvelezmagic.com/)

# %% [markdown]
# ## Configuración de ambiente de trabajo

# %% [markdown]
# ```bash
# pip install --upgrade pip
# ```

# %% [markdown]
# ```bash
# pip install pyjanitor matplotlib==3.5.1 missingno numpy pandas pyreadr seaborn session-info upsetplot==0.6.1
# ```
#
# or
#
# ```bash
# pip install -r requirements.txt
# ```

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Importar librerías

# %%
# %pip install --upgrade pip
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pip in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (22.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyjanitor in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 1)) (0.23.1)
# Requirement already satisfied: missingno in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: numpy in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: matplotlib==3.5.1 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: pandas in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: pyreadr in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 6)) (0.4.7)
# Requirement already satisfied: seaborn in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 7)) (0.11.2)
# Requirement already satisfied: session-info in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: upsetplot==0.6.1 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from -r ../requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from matplotlib==3.5.1->-r ../requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pandas-flavor in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pyjanitor->-r ../requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: natsort in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pyjanitor->-r ../requirements.txt (line 1)) (7.1.1)
# Requirement already satisfied: multipledispatch in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pyjanitor->-r ../requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: scipy in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pyjanitor->-r ../requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: pytz>=2020.1 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pandas->-r ../requirements.txt (line 5)) (2022.1)
# Requirement already satisfied: stdlib-list in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from session-info->-r ../requirements.txt (line 8)) (0.8.0)
# Requirement already satisfied: six>=1.5 in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.5.1->-r ../requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: xarray in /home/mazzaroli/anaconda3/envs/missing_data/lib/python3.9/site-packages (from pandas-flavor->pyjanitor->-r ../requirements.txt (line 1)) (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import missing_data.utils.paths as path
import janitor
import matplotlib.pyplot as plt
import missingno
import numpy as np
import pandas as pd
import pyreadr
import seaborn as sns
import session_info
import upsetplot

# %% [markdown]
# ## Importar funciones personalizadas

# %%
# %run ../missing_data/utils/pandas-missing-extension.ipynb

# %% [markdown]
# ## Configurar el aspecto general de las gráficas del proyecto

# %%
# %matplotlib inline

sns.set(
    rc={
        "figure.figsize": (10, 10)
    }
)

sns.set_style("whitegrid")

# %% [markdown]
# ## Operar con valores faltantes

# %% [markdown]
# ### Python

# %%
print(
    None or True,
    None or False,
    None == None,
    None is None,
    # None + True,
    type(None),
    sep='\n'
)
# Out:
# True
# False
# True
# True
# <class 'NoneType'>

# %% [markdown]
# ### NumPy

# %%
print(
    np.nan or True,
    np.nan == np.nan,
    np.nan is np.nan,
    type(np.nan),
    np.isnan(np.nan),
    sep='\n'
)
# Out:
# nan
# False
# True
# <class 'float'>
# True

# %% [markdown]
# ### Pandas

# %%
test_missing_df = pd.DataFrame.from_dict(
    data=dict(
        x=[0,1, np.nan, np.nan, None],
        y=[0,1, pd.NA,  np.nan, None]
    )
)
test_missing_df
# Out:
#      x     y
# 0  0.0     0
# 1  1.0     1
# 2  NaN  <NA>
# 3  NaN   NaN
# 4  NaN  None

# %%
test_missing_df.isna()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2   True   True
# 3   True   True
# 4   True   True

# %%
test_missing_df.isnull()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2   True   True
# 3   True   True
# 4   True   True

# %%
test_missing_df.x.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: x, dtype: bool

# %%
pd.Series([1, np.nan])
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %%
pd.Series([pd.to_datetime('2022-01-01'), np.nan])
# Out:
# 0   2022-01-01
# 1          NaT
# dtype: datetime64[ns]

# %%
pd.Series([-1]).isnull()
# Out:
# 0    False
# dtype: bool

# %% [markdown]
# ## Cargar los conjuntos de datos

# %% [markdown]
# ### Pima Indians Diabetes

# %%
pima_indians_diabetes_url = 'https://nrvis.com/data/mldata/pima-indians-diabetes.csv'

# %%
# !wget -O ../data/pima-indians-diabetes.csv { pima_indians_diabetes_url } -q

# %%
diabetes_df = pd.read_csv (
    path.data_dir('pima-indians-diabetes.csv'), # or pima_indians_diabetes_url
    sep=',',
    names=[
        "pregnancies",
        "glucose",
        "blood_pressure",
        "skin_thickness",
        "insulin",
        "bmi",
        "diabetes_pedigree_function",
        "age",
        "outcome",
    ]
)

# %%
diabetes_df.head()
# Out:
#    pregnancies  glucose  blood_pressure  skin_thickness  insulin   bmi  \
# 0            6      148              72              35        0  33.6
# 1            1       85              66              29        0  26.6
# 2            8      183              64               0        0  23.3
# 3            1       89              66              23       94  28.1
# 4            0      137              40              35      168  43.1
#
#    diabetes_pedigree_function  age  outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1

# %% [markdown]
# ### naniar (oceanbuoys, pedestrian, riskfactors)

# %% [markdown]
# #### Crear unidades de información de los conjuntos de datos

# %%
base_url = "https://github.com/njtierney/naniar/raw/master/data/"
datasets_names = ("oceanbuoys", "pedestrian", "riskfactors")
extension = ".rda"

# %% [markdown]
# #### Descargar y cargar los conjuntos de datos

# %%
datasets_dfs = {}

for dataset_name in datasets_names:
    dataset_file = f'{ dataset_name }{ extension }'
    dataset_output_file = path.data_dir(dataset_file)
    dataset_url = f'{base_url}{dataset_file}'

    # !wget -q -O { dataset_output_file } { dataset_url }

    datasets_dfs[f"{ dataset_name }_df"] = pyreadr.read_r(dataset_output_file).get(dataset_name)

datasets_dfs.keys()
# Out:
# dict_keys(['oceanbuoys_df', 'pedestrian_df', 'riskfactors_df'])

# %% [markdown]
# #### Incluir conjuntos de datos en nuestro ambiente local

# %%
locals().update(**datasets_dfs)
del datasets_dfs

# %% [markdown]
# ### Verificar carga

# %%
oceanbuoys_df.shape, pedestrian_df.shape, riskfactors_df.shape, diabetes_df.shape
# Out:
# ((736, 8), (37700, 9), (245, 34), (768, 9))

# %% [markdown]
# ## Tabulación de valores faltantes

# %%
riskfactors_df
# Out:
#     state     sex  age weight_lbs height_inch    bmi   marital pregnant  \
# 0      26  Female   49        190          64  32.68   Married      NaN
# 1      40  Female   48        170          68  25.90  Divorced      NaN
# 2      72  Female   55        163          64  28.04   Married      NaN
# 3      42    Male   42        230          74  29.59   Married      NaN
# 4      32  Female   66        135          62  24.74   Widowed      NaN
# ..    ...     ...  ...        ...         ...    ...       ...      ...
# 240    10  Female   79        144          63  25.56   Widowed      NaN
# 241    46    Male   45        170          74  21.87  Divorced      NaN
# 242    15    Male   62        175          71  24.46  Divorced      NaN
# 243    34  Female   62        138          64  23.74   Married      NaN
# 244    18    Male    9        200          70  28.76   Married      NaN
#
#      children education  ... smoke_100 smoke_days smoke_stop smoke_last  \
# 0           0         6  ...        No        NaN        NaN        NaN
# 1           0         5  ...        No        NaN        NaN        NaN
# 2           0         4  ...        No        NaN        NaN        NaN
# 3           1         6  ...        No        NaN        NaN        NaN
# 4           0         5  ...       Yes   Everyday        Yes        NaN
# ..        ...       ...  ...       ...        ...        ...        ...
# 240         0         4  ...        No        NaN        NaN        NaN
# 241         2         4  ...        No        NaN        NaN        NaN
# 242         0         6  ...       Yes    Not@All        NaN          7
# 243         0         4  ...       Yes   Everyday         No        NaN
# 244         0         4  ...       Yes    Not@All        NaN          7
#
#     diet_fruit  diet_salad  diet_potato diet_carrot diet_vegetable diet_juice
# 0         1095         261          104         156            521         12
# 1           52         209           52           0             52          0
# 2           36         156           52          24             24         24
# 3          NaN         NaN          NaN         NaN            NaN        NaN
# 4           -7         261          209         261            365        104
# ..         ...         ...          ...         ...            ...        ...
# 240         -7          -7           -7          -7             -7         -7
# 241         52          52           52          24             52         24
# 242        365         156          104          52            730        365
# 243        730           0           24         156            104          0
# 244         52         104           52           0            104        104
#
# [245 rows x 34 columns]

# %%
riskfactors_df.missing.missing_upsetplot()
# Out:
# {'matrix': <AxesSubplot:>,
#  'shading': <AxesSubplot:>,
#  'totals': <AxesSubplot:>,
#  'intersections': <AxesSubplot:ylabel='Intersection size'>}

# %% [markdown]
# ### Resúmenes básicos de valores faltantes

# %% [markdown]
# #### Número total de valores completos (sin observaciones faltantes)

# %% [markdown]
# #### Número total de valores faltantes

# %% [markdown]
# ### Resúmenes tabulares de valores faltantes

# %% [markdown]
# #### Variables / Columnas

# %% [markdown]
# ##### Resumen por variable

# %% [markdown]
# ###### Tabulación del resumen por variable

# %% [markdown]
# #### Casos / Observaciones / Filas

# %% [markdown]
# ##### Resúmenes por caso

# %% [markdown]
# ###### Tabulación del resumen por caso

# %% [markdown]
# ### Intervalos de valores faltantes

# %% [markdown]
# ### _Run length_ de valores faltantes

# %% [markdown]
# ## Visualización inicial de valores faltantes

# %% [markdown]
# ### Variable

# %% [markdown]
# ### Casos / Observaciones / Filas

# %% [markdown]
# ## Codificación de valores faltantes

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <p>
#     Al igual que cada persona es una nueva puerta a un mundo diferente, los <b>valores faltantes</b> existen en diferentes formas y colores. Al trabajar con valores faltantes será crítico entender sus distintas representaciones. A pesar de que el conjunto de datos de trabajo pareciera que no contiene valores faltantes, deberás ser capaz de ir más allá de lo observado a simple vista para remover el manto tras el cual se esconde lo desconocido.
#     </p>
# </div>

# %% [markdown]
# ### Valores comúnmente asociados a valores faltantes

# %% [markdown]
# #### Cadenas de texto

# %%
common_na_strings = (
    "missing",
    "NA",
    "N A",
    "N/A",
    "#N/A",
    "NA ",
    " NA",
    "N /A",
    "N / A",
    " N / A",
    "N / A ",
    "na",
    "n a",
    "n/a",
    "na ",
    " na",
    "n /a",
    "n / a",
    " a / a",
    "n / a ",
    "NULL",
    "null",
    "",
    "?",
    "*",
    ".",
)

# %% [markdown]
# #### Números

# %%
common_na_numbers = (-9, -99, -999, -9999, 9999, 66, 77, 88, -1)

# %% [markdown]
# ### ¿Cómo encontrar los valores comúnmente asociados a valores faltantes?

# %%
missing_data_example_df = pd.DataFrame.from_dict(
    dict(
        x = [1, 3, "NA", -99, -98, -99],
        y = ["A", "N/A", "NA", "E", "F", "G"],
        z = [-100, -99, -98, -101, -1, -1]
    )
)

missing_data_example_df
# Out:
#      x    y    z
# 0    1    A -100
# 1    3  N/A  -99
# 2   NA   NA  -98
# 3  -99    E -101
# 4  -98    F   -1
# 5  -99    G   -1

# %% [markdown]
# #### Revisar tipos de datos

# %% [markdown]
# #### Revisar valores únicos de los datos

# %% [markdown]
# ### Sustituyendo valores comúnmente asociados a valores faltantes

# %% [markdown]
# #### Sustitución desde la lectura de datos

# %% [markdown]
# #### Sustitución global

# %% [markdown]
# #### Sustitución dirigida

# %% [markdown]
# ## Conversión de valores faltantes implícitos a explícitos

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <br>
#     <br>
#     <p>
#         <i>
#         "<b>Implícito</b> se refiere a todo aquello que se entiende que está incluido
#         pero sin ser expresado de forma directa o explícitamente."
#         </i>
#     </p>
#     <p>
#     Un <code>valor faltante implícito</code> indica que el valor faltante <b>debería estar incluido</b>
#     en el conjunto de datos del análisis, <b>sin que éste lo diga</b> o lo <b>especifique</b>.
#     Por lo general, son valores que podemos encontrar al pivotar nuestros datos
#     o contabilizar el número de apariciones de combinaciones de las variables de estudio.
#     </p>
# </div>

# %%
implicit_to_explicit_df = pd.DataFrame.from_dict(
    data={
        "name": ["lynn", "lynn", "lynn", "zelda"],
        "time": ["morning", "afternoon", "night", "morning"],
        "value": [350, 310, np.nan, 320]
    }
)

implicit_to_explicit_df
# Out:
#     name       time  value
# 0   lynn    morning  350.0
# 1   lynn  afternoon  310.0
# 2   lynn      night    NaN
# 3  zelda    morning  320.0

# %% [markdown]
# ### Estrategias para la identificación de valores faltantes implícitos

# %% [markdown]
# #### Pivotar la tabla de datos

# %% [markdown]
# #### Cuantificar ocurrencias de n-tuplas

# %% [markdown]
# ### Exponer filas faltantes implícitas a explícitas

# %% [markdown]
# <div class="alert alert-info">
#     <b style="font-size: 1.5em;">📘 Información</b>
#     <p>
#        <a href="https://pyjanitor-devs.github.io/pyjanitor/api/functions/#janitor.functions.complete.complete", class="alert-link"><code>janitor.complete()</code></a> está modelada a partir de la función <a href="https://tidyr.tidyverse.org/reference/complete.html", class="alert-link"><code>complete()</code></a> del paquete <a href="https://tidyr.tidyverse.org/index.html", class="alert-link"><code>tidyr</code></a> y es un <i>wrapper</i> alrededor de <a href="https://pyjanitordevs.github.io/pyjanitor/api/functions/#janitor.functions.expand_grid.expand_grid", class="alert-link"><code>janitor.expand_grid()</code></a>, <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html", class="alert-link"><code>pd.merge()</code></a> y <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html", class="alert-link"><code>pd.fillna()</code></a>. En cierto modo, es lo contrario de <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html", class="alert-link"><code>pd.dropna()</code></a>, ya que expone implícitamente las filas que faltan.
#     </p>
#     <p>
#     Son posibles combinaciones de nombres de columnas o una lista/tupla de nombres de columnas, o incluso un  diccionario de nombres de columna y nuevos valores.
#     </p>
#     <p>
#     Las columnas <a href="https://pandas.pydata.org/docs/user_guide/advanced.html"><code>MultiIndex</code></a> no son complatibles.
#     </p>
# </div>

# %% [markdown]
# #### Exponer n-tuplas de valores faltantes
#
# Ejemplo, encontrar los pares faltantes de `name` y `time`.

# %% [markdown]
# #### Limitar la exposición de n-tuplas de valores faltantes

# %% [markdown]
# #### Rellenar los valores faltantes

# %% [markdown]
# #### Limitar el rellenado de valores faltantes implícitos

# %% [markdown]
# ## Tipos de valores faltantes

# %% [markdown]
# ### _Missing Completely At Random_ (MCAR)

# %% [markdown]
# ### _Missing At Random_ (MAR)

# %% [markdown]
# ### _Missing Not At Random_ (MNAR)

# %% [markdown]
# ## Concepto y aplicación de la matriz de sombras (_i.e._, _shadow matrix_)

# %% [markdown]
#  ### Construcción de la matriz de sombras

# %% [markdown]
# ### Utilizar función de utilería `bind_shadow_matrix()`

# %% [markdown]
# ### Explorar estadísticos utilizando las nuevas columnas de la matriz de sombras

# %% [markdown]
# ## Visualización de valores faltantes en una variable

# %% [markdown]
# ## Visualización de valores faltantes en dos variables

# %% [markdown]
# ## Correlación de nulidad

# %% [markdown]
# ## Eliminación de valores faltantes

# %% [markdown]
# <div class="alert alert-warning", role="alert">
#     <b style="font-size: 1.5em;">🚧 Advertencia</b>
#     <p>
#     La eliminación de valores faltantes <b>asume</b> que los valores faltantes están perdidos
#     completamente al azar (<code>MCAR</code>). En cualquier otro caso, realizar una
#     eliminación de valores faltantes podrá ocasionar <b>sesgos</b> en los
#     análisis y modelos subsecuentes.
#     </p>
# </div>

# %% [markdown]
# Primero observa el número total de observaciones y variables que tiene tu conjunto de datos.

# %% [markdown]
# ### _Pairwise deletion_ (eliminación por pares)

# %% [markdown]
# ### _Listwise Deletion or Complete Case_ (Eliminación por lista o caso completo)

# %% [markdown]
# #### Con base en 1 columna

# %% [markdown]
# #### Con base en 2 o más columnas

# %% [markdown]
# ### Representación gráfica tras la eliminación de los valores faltantes

# %% [markdown]
# ## Imputación básica de valores faltantes

# %% [markdown]
# ### Imputación con base en el contexto

# %%
implicit_to_explicit_df = pd.DataFrame(
    data={
        "name": ["lynn", np.nan, "zelda", np.nan, "shadowsong", np.nan],
        "time": ["morning", "afternoon", "morning", "afternoon", "morning", "afternoon",],
        "value": [350, 310, 320, 350, 310, 320]
    }
)

implicit_to_explicit_df
# Out:
#          name       time  value
# 0        lynn    morning    350
# 1         NaN  afternoon    310
# 2       zelda    morning    320
# 3         NaN  afternoon    350
# 4  shadowsong    morning    310
# 5         NaN  afternoon    320

# %% [markdown]
# ### Imputación de un único valor

# %% [markdown]
# ## Continúa aprendiendo sobre el manejo de valores faltantes

# %% [markdown]
# <div class="alert alert-success">
#     <b style="font-size: 1.5em;">✅ ¡Felicidades por terminar el curso!</b>
#     <p>
# Has aprendido bastante sobre la exploración y manipulación de valores faltantes.
#     </p>
#     <p>
# Empezaste conociento las principales operaciones al trabajar con valores faltantes. Ahora, eres consciente de que estas operaciones no son universales y cada software decide tratar a los valores faltantes a su conveniencia.
#     </p>
#     <p>
# Y, hablando de conveniencias, comenzaste tu camino en la exploración de valores faltantes a través de una representación universal de qué es lo que faltaba. No obstante, no pasó mucho para darte cuenta de que los valores faltantes pueden existir en formas muy variables. Incluso, en formas en las que no sabemos que nos faltan estos valores en sí mismos.
#     </p>
#     <p>
# Con los valores faltantes ya expuestos, te conviertes en una persona capaz de explorarlos en profundidad de forma estadística y visual. Entendiendo así, los distintos mecanismos que pueden tener los valores faltantes: MCAR, MAR y MNAR.
#     </p>
#     <p>
# A su vez, aprendiste las bases sobre cómo tratarlos a través de la eliminación de elementos o la imputación de valores de una forma básica y sencilla. Por lo tanto, necesitarás continuar tu camino de aprendizaje con un curso que te permita profundizar en estas técnicas de tratamiento para valores faltantes.
#     </p>
#     <p>
# Te recomiendo continuar con mi <a href="https://platzi.com/cursos/datos-faltantes-imputacion/">Curso de Manejo de Datos Faltantes: Imputación</a>. Estoy seguro de que tus habilidades adquiridas hasta el momento mejorarán, permitiéndote realizar análisis cada vez más complejos y cercanos al mundo real.
#     </p>
#     <p>
#     Con mucha alegría por tu logro,
#    Jesús Vélez Santiago
#     </p>
#
# </div>

# %% [markdown]
# ## Información de sesión

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# janitor             0.23.1
# matplotlib          3.5.1
# missing_data        NA
# missingno           0.5.1
# numpy               1.22.4
# pandas              1.4.3
# pyreadr             0.4.7
# seaborn             0.11.2
# session_info        1.0.0
# upsetplot           0.6.1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.2.0
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.5
# cffi                        1.15.1
# colorama                    0.4.5
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# entrypoints                 0.4
# executing                   0.8.3
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.6.5
# jedi                        0.18.1
# jupyter_server              1.18.1
# kiwisolver                  1.4.2
# matplotlib_inline           NA
# mpl_toolkits                NA
# multipledispatch            0.6.0
# natsort                     7.1.1
# nbinom_ufunc                NA
# numexpr                     2.8.3
# packaging                   21.3
# pandas_flavor               NA
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pyprojroot                  0.2.0
# pytz                        2022.1
# scipy                       1.7.3
# setuptools                  61.2.0
# six                         1.16.0
# stack_data                  0.2.0
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# xarray                      0.20.1
# zmq                         23.2.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.4.0
# jupyter_client      7.2.2
# jupyter_core        4.10.0
# jupyterlab          3.4.4
# notebook            6.4.12
# -----
# Python 3.9.12 (main, Jun  1 2022, 11:38:51) [GCC 7.5.0]
# Linux-5.4.72-microsoft-standard-WSL2-x86_64-with-glibc2.31
# -----
# Session information updated at 2022-11-08 13:29
# </pre>
# </details>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4a53f17a-b7be-4f70-ac67-4fdbea459e36' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
